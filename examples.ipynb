# %% [markdown]
# # Tensor-tools examples
#
# This notebook demonstrates the core operations implemented in `toolbox/tensorLinalg.py`.

# %% [markdown]
# 1. First install the package.

# %%
# Install from GitHub (requires the latest pyproject.toml fixes to be pushed)
# !pip install -q --no-cache-dir "git+https://github.com/jnlandu/tensor-tensor-toolbox-in-python.git"

# If you created a tag, prefer pinning:
# !pip install -q --no-cache-dir "git+https://github.com/jnlandu/tensor-tensor-toolbox-in-python.git@v0.1.0"
# Out:
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [53 lines of output]
#       /private/var/folders/c0/yycmqs6n025cf5d24rf0j6pr0000gp/T/pip-build-env-8wdmcna1/overlay/lib/python3.13/site-packages/setuptools/config/_apply_pyprojecttoml.py:55: SetuptoolsDeprecationWarning: 'tool.setuptools.license-files' is deprecated in favor of 'project.license-files' (available on setuptools>=77.0.0).
#       !!
#
#               ********************************************************************************
#
#               By 2026-Feb-18, you need to update your project and remove deprecated calls
#               or your builds will no longer be supported.
#
#               See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license-files for details.
#               ********************************************************************************
#
#       !!
# ...

# %%
## Check if it well installed
import tensor_toolbox
print(tensor_toolbox.__version__())
# Out:
# 0.1.0
